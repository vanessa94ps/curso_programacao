# %%
nome_usuario = input("insira seu nome:")
print( f"Olá, {nome_usuario}! Bem vindo ao Pascoland")
data_usuario = input("qual à data de entrega")
quantidade_usuario = int( input("qual a quantidade de ovos de chocolate") )
gramas_usuario = int( input("quantas gramas os ovos terá" ) )
gramas_por_quilo = 100
total_gramas = gramas_usuario * quantidade_usuario
total_gramas_por_quilo = total_gramas * gramas_por_quilo
print(f" Opeso total dos ovos é:{total_gramas}, o valor total da sua encomenda é de  {total_gramas_por_quilo}")
# Out:
# insira seu nome:vany
# Olá, vany! Bem vindo ao Pascoland
# qual à data de entrega19/08
# qual a quantidade de ovos de chocolate3
# quantas gramas os ovos terá250
#  Opeso total dos ovos é:750, o valor total da sua encomenda é de  75000
